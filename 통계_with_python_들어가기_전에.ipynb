# %% [markdown]
# <a href="https://colab.research.google.com/github/ehpub/statistics_python/blob/main/%ED%86%B5%EA%B3%84_with_python_%EB%93%A4%EC%96%B4%EA%B0%80%EA%B8%B0_%EC%A0%84%EC%97%90.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 사용할 모듈

# %%
import scipy as sp
from scipy import stats

# %%
help(sp)
# Out:
# Help on package scipy:
#
# NAME
#     scipy
#
# DESCRIPTION
#     SciPy: A scientific computing package for Python
# ...
#
#     Documentation is available in the docstrings and
#     online at https://docs.scipy.org.
#
#     Contents
#     --------
#     SciPy imports all the functions from the NumPy namespace, and in
#     addition provides:
#
#     Subpackages
#     -----------
#     Using any of these subpackages requires an explicit import. For example,
#     ``import scipy.cluster``.
#
#     ::
#
#      cluster                      --- Vector Quantization / Kmeans
#      datasets                     --- Dataset methods
#      fft                          --- Discrete Fourier transforms
#      fftpack                      --- Legacy discrete Fourier transforms
#      integrate                    --- Integration routines
#      interpolate                  --- Interpolation Tools
#      io                           --- Data input and output
# ...

# %% [markdown]
# ## 참고 사이트
#
# https://docs.scipy.org/doc/scipy/
#
# https://docs.scipy.org/doc/scipy/tutorial/stats.html

# %% [markdown]
# ## 분포
#
#
# *   연속 분포
# *   불연속 분포(이산 분포)

# %% [markdown]
# ### 연속 분포

# %%
from scipy.stats import chi2 #카이제곱분포
from scipy.stats import expon   #지수 분포
from scipy.stats import f #F분포
from scipy.stats import norm #정규 분포
from scipy.stats import t #t분포
from scipy.stats import uniform #균일 분포

# %% [markdown]
# ### 불연속 분포

# %%
from scipy.stats import binom #이항 분포
from scipy.stats import poisson #포아송 분포
